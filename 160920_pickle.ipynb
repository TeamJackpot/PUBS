# %%
import pickle

# read in pickle files
allele_dict = pickle.load(open("allele_dic.pkl", "rb"))
aminotonumber_dict = pickle.load(open("aminotonumber.pkl", "rb"))
translate_dict = pickle.load(open("translate.pkl", "rb"))

print(allele_dict)
# Out:
# {'GTTAGTTGTCAGCGGCCC': ['30_CAC'], 'TATGCATTTCGTTACTAA': ['66_CTA'], 'GTTTTGACGCTCAATTGT': ['60_CAC'], 'TCAACGGTAGCGTACTAG': ['46_AGC'], 'CAGCAAGATTACGGCCCA': ['28_CGC'], 'ATTGGTCTAGGGGGGGTG': ['32_CGT'], 'CAATACAAGCACACTGTT': ['62_GCC'], 'GGGACATGGCACATGTGG': ['48_ACA'], 'CAAGGGGGCTATTCAAGA': ['73_CCG'], 'GAGTCTCCAGGCCTAGCG': ['27_TGA'], 'AGGATATGTGGCGGGGGT': ['68_TAG'], 'ACATGTAATTATTTCATT': ['29_AGC'], 'GTTGCGGGGGAGCAGTGC': ['35_CCT'], 'GATTTAATGTACTGCATG': ['6_GCC'], 'TAACGAAAAATACATATA': ['40_GTT'], 'AGGAACCCTCCCGTCCAT': ['11_CTC'], 'TTGAGGCCTGGGCATTTT': ['36_TAG'], 'TGGGGGCGCACGGGACCC': ['7_CCC'], 'ACGAGGAACCCGCACATT': ['8_TAG'], 'AGGTTGCGCACCGATATT': ['31_GAC'], 'GTGAGAGTAGCCCCGACC': ['72_GAA'], 'CCTACCTATTACTCGAAG': ['37_ACG'], 'ACGCATCCTGGAGACTAC': ['55_ACC'], 'TCGCGAAGGGTATACGGT': ['10_AGG'], 'TTGTCGGGGGATAGGAAG': ['22_CTC'], 'GTCCGGGGGGGGCGCACG': ['43_CAC'], 'CGTCCCCCAGACTATTCT': ['32_CCG'], 'TCGGCTGAAGTGGAGCGG': ['21_CGA'], 'GTCGCGGCCATATATTCG': ['67_TAC'], 'GCGCCCCTTGACCACTTC': ['41_AAC'], 'TACTTTTCCAAATTGAAG': ['75_TCC'], 'TCAGCGAGGCCGGTCCGC': ['2_GCT'], 'TTAGGAGTGTTCTTTCCC': ['75_ATC'], 'ACAACGGTTTCGCATCCG': ['62_ATC'], 'AACTTCTGAGGGCAATTC': ['30_GAA'], 'GTAAAGTCTTGTTGCAAT': ['23_GCT'], 'GACAAGACTCATTTTAGC': ['2_ACT'], 'GTTTAGCCTTATACGACA': ['18_GAC'], 'GTCCTGGGCTAAGCAAAA': ['44_GGC'], 'CCTCGCACCTTATAGGCC': ['72_AGT'], 'GTAACTGTTCCCTCAAGG': ['45_GCG'], 'TCCAAAGCAAAAGACTAG': ['44_CCT'], 'CAAGACCGTAGCATTATA': ['64_GGT'], 'GCTACCACAACCACAACT': ['61_CCC'], 'CCGCAATCAGGCAGTTAA': ['35_GTC'], 'AAAACATCTCGTATTAAC': ['38_CAC'], 'ATGTCAACTATAGGTCAG': ['63_TGT'], 'TTTTGCCGCTAGGAAGGG': ['65_CCA'], 'AGAATTCAGGTCCGCGAC': ['47_AGG'], 'AAGGACGTAGATGGGTCT': ['74_GGG'], 'CAATAAACTAATGGAAAA': ['73_AAA'], 'GATAGTAACAATTACGAC': ['25_CTC'], 'GCTTCGATGAGGACCTTG': ['32_GCA'], 'ATGCTCTCTAATCAACGT': ['68_AGG'], 'GAAGGGATTCCACGGTTT': ['12_GAC'], 'TGGCCCCTGCGCAATACG': ['8_CAG'], 'TCTTTCAATACGTTAAGG': ['34_CGA'], 'AGGCGAAACGGTGTATAA': ['51_GGC'], 'TGGTGATTTCTACTTGAA': ['58_GTG'], 'GACGGGCTTAAGTCGGCG': ['35_GTG'], 'CAATTGCTCCTGAGACCA': ['22_TTG'], 'ATCCCGGACGCGTGCACA': ['64_TAT'], 'CTATACTACGTCGCCATA': ['64_TAT'], 'GGACGTGGGTCTCAAGCA': ['5_GGG'], 'AGTTCCCCGCTACCCACC': ['40_ATT'], 'CGCAACGAGCAGTTAGGA': ['66_CAT'], 'CCCAGGCCGGGGAATGAG': ['18_CCG'], 'GGATGACTGTCATCGGCT': ['62_AAT'], 'CGATACTCCATTGAGAAT': ['15_TAC'], 'CCATTAACCAAATAGTGC': ['53_GAT'], 'ATGCTGCGTCAATAGCGT': ['55_CCC'], 'CTTAATCCCTCTGTTGAG': ['63_CTG'], 'TCTTGTAACGTGGTCTAG': ['24_ACC'], 'ACCCTAGACATATCACAT': ['67_CGA'], 'ACTATGCAAGATAAGCGC': ['29_AGC'], 'CTAGCATAAAATTTTGGG': ['74_TCG'], 'TTGGGTAAATCTAGGGGC': ['28_CAC'], 'TTAAGAGCTCTCGTTTGT': ['15_AGC'], 'AAGGCGCACTTGCAAGGC': ['4_ATA'], 'GTTCTCCATTTAATAAGA': ['9_AGG'], 'TGATCATCCTATACGTGG': ['60_TTT'], 'GGTCCGCCCCCTAGACGG': ['32_TAG'], 'CATACCGTATTGGGGTCG': ['17_TAT'], 'CGGGTGGTGTGCGTTTAA': ['9_CCG'], 'TCACCTAGATACAAGCAG': ['53_TCG'], 'GAATCCAGAGGGATGCTG': ['48_GCG'], 'AGCGTTATGTATTATTAA': ['27_TGA'], 'ACAGCGACGAGGGGGGGC': ['31_TCT'], 'CACGCGCGATCAAAGCAC': ['46_CGG'], 'CATAGGGGGCCCCTGGGC': ['46_TGT'], 'GACCGAATTCTTAACCTC': ['70_ATT'], 'ATCGCAGTGCGTTCGTGC': ['7_CTC'], 'AAGCGGTTATGATGCGAA': ['7_CAC'], 'AGCGCAAAAATGTGGCCG': ['15_CTG'], 'TCAGGAGGGAGGCTTCCG': ['29_GCC'], 'ATACTTTGGGCACCAGTA': ['63_CCT'], 'TTAATAAAGAATTGATGT': ['3_GCA'], 'TTGATGAACTACATTTCT': ['14_CGA'], 'GTCTACTGTCTCGCTGTA': ['65_GGA'], 'AACGCGTACTATCTTCAT': ['37_CGT'], 'GCCACTGTCCGAAAGTAG': ['49_GGC'], 'GGCCTGGAAGAGTGGCGT': ['10_CTC'], 'ACATAAGAGTGTGAGGGT': ['26_GAC'], 'GCATGAACCACGCAGGCT': ['64_TCA'], 'GCGGGGCTTACATAACAT': ['27_ACA'], 'TTTTAGAAATACTGTTTG': ['71_TAA'], 'ACACCCGCTGCAATAGAA': ['14_GCC'], 'CGATGCCGAAAAATGGAT': ['15_GAC'], 'GACCGAGATCTTGCGAAG': ['25_CAG'], 'AGCCCTAAGCCACCGATT': ['33_ACC'], 'ACCTAAAATTTTGGATAA': ['3_CAC'], 'CAGGGAGAGAGGGGCCTC': ['55_GAC'], 'TACATAGCGAGGTAGAGA': ['72_TTT'], 'TCCGCGGACAATGGAGTG': ['42_GTT'], 'CGGTGCGCACCCTAACTT': ['4_GAG'], 'CTGAATAACCTACGAAAT': ['27_TTG'], 'CAAACCACACATGTGCCG': ['40_GGC'], 'CCCCTATAAAGAACTGTG': ['36_GCT'], 'T ...

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

a = np.random.random((16, 16))
b = np.random.randn(10000)
print(b)
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()
# Out:
# [-0.65697391 -0.18955552  0.94837034 ..., -0.16563105 -0.58372649
#   0.72849136]

# %%
print('hello world')
